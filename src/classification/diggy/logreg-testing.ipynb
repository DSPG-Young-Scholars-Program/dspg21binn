# %%
## Importing all relevant libraries

import random

import numpy as np
import pandas as pd

from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn import svm
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score


from transformers import pipeline
from transformers import AutoTokenizer, AutoModel, AutoModelForPreTraining
from transformers import BigBirdConfig

import torch

import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
# !pwd
# Out:
# /sfs/qumulo/qhome/far3jh/git/dspg21binn/src/classification/diggy

# %%
df_new = pd.read_csv("/project/class/bii_sdad_dspg/uva_2021/binn/DNA_Food_Articles_2017_no_rep.csv", index_col=0) ## Reading in data
#df_save = df.reset_index(inplace=False, drop = True)
df_new = df_new.reset_index(inplace=False, drop = True)
df_new = df_new.iloc[0:20,]
df_new.head(2)
# Out:
#    index                                          copyright subject_codes  \
# 0     15  © Copyright 2017 Journal of Engineering via Ve...        ,ccat,
# 1     18  © Copyright 2017 Computer Weekly News via via ...        ,ccat,
#
#    art  modification_datetime  \
# 0  NaN          1489442488000
# 1  NaN          1487890959000
#
#                                                 body  \
# 0  Those respondents with advanced full life cycl...
# 1  The Access Valve for ThingWorx integrates an o...
#
#    company_codes_occur_ticker_exchange company_codes_occur  \
# 0                                  NaN            ,comasc,
# 1                                  NaN                 NaN
#
#   company_codes_about company_codes_lineage  ...           company_codes  \
# 0            ,comasc,                   NaN  ...  ,comasc,comasc,comasc,
# 1                 NaN                   NaN  ...                     NaN
#
#                                       industry_codes  \
# 0      ,imobsoft,i3302,i330202,i3302021,icomp,itech,
# 1  ,isecpri,iioft,i3302,i330202,i3302021,i3303,ic...
#
#                                                title  publication_datetime  \
# 0  CA Technologies; Are You Getting the Most Valu...         1489363200000
# 1  Certified Security Solutions, Inc. CSS Release...         1487808000000
#
#   publisher_name action document_type                     date  year  \
# 0    NewsRX, LLC    add       article  2017-03-13 00:00:00.000  2017
# 1    NewsRX, LLC    add       article  2017-02-23 00:00:00.000  2017
#
#                                            full_text
# 0  CA Technologies; Are You Getting the Most Valu...
# 1  Certified Security Solutions, Inc. CSS Release...
#
# [2 rows x 45 columns]

# %%
df_new.company_codes = df_new.company_codes.str.strip(",") ## Commas at the start
df_new.company_codes = df_new.company_codes.str.split(",",expand=False) ## List
df_new.company_codes = df_new.company_codes.replace(np.NaN, "") ## Getting rid of floats to convert to sets

for i in range(len(df_new)):
    df_new.company_codes.loc[i] = list(set(df_new.company_codes.loc[i])) ## Unique companies list

max_companies = 0
for row in df_new.company_codes:
    max = len(row)
    if max > max_companies:
        max_companies = max
        
list_of_column_labels = []

for i in range(max_companies):
    list_of_column_labels.append("company_name_"+str(i+1))
    
df_new = df_new.join(pd.DataFrame(df_new.company_codes.to_list(), columns = list_of_column_labels))
# Out:
# /home/far3jh/.conda/envs/DiggyConda/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
# Out:
#     index                                          copyright  \
# 0      15  © Copyright 2017 Journal of Engineering via Ve...
# 1      18  © Copyright 2017 Computer Weekly News via via ...
# 2      26  Copyright 2017 Telecompaper. All Rights Reserv...
# 3      36  © Copyright 2017 GlobeNewswire, Inc. All Right...
# 4      57  © Copyright 2017 Computer Weekly News via via ...
# 5      78  © Copyright 2017 Information Technology Newswe...
# 6     107           © 2017 Condé Nast. All rights reserved.
# 7     124   © 2017, M2 Communications. All rights reserved.
# 8     125  © Copyright 2017 Computer Weekly News via via ...
# 9     142   © 2017, M2 Communications. All rights reserved.
# 10    145  © 2017, Namibian Sun, All rights Reserved - Pr...
# 11    180  © Copyright 2017 Marketing Weekly News via Ver...
# 12    198  © 2017, Ventures Africa, All rights Reserved -...
# 13    218  Copyright 2017 Northwest Herald, The (Crystal ...
# 14    226  © Copyright 2017 Agriculture Week via NewsRx.com
# 15    232  (c) 2017.  The Associated Press.  All Rights R...
# 16    253  © 2017 American City Business Journals, Inc. A...
# 17    278  © Copyright 2017 Information Technology Newswe...
# 18    285  © Copyright 2017 Computer Weekly News via via ...
# 19    289                      © 2017, Herald & Times Group
#
#                                         subject_codes          art  \
# 0                                              ,ccat,          NaN
# 1                                              ,ccat,          NaN
# 2             ,ccat,c22,cprdop,c24,ncat,nfact,nfcpin,          NaN
# 3                ,cpartn,ccpint,npress,c11,ccat,ncat,          NaN
# 4                                              ,ccat,          NaN
# 5                           ,c133,ccat,cgymtr,cinprp,          NaN
# 6   ,gcvir,gdip,ghack,gspy,gcat,gcns,gcrim,gpir,nc...  CHAD HAGEN
# 7                                    ,guni,gcat,gedu,          NaN
# 8               ,c133,gdatap,ccat,cgymtr,cinprp,gcat,          NaN
# 9   ,cpartn,ccexpi,ccrm,npress,c31,ccat,ncat,nfact...          NaN
# 10                  ,c314,c31,ccat,ncat,nfact,nfcpin,          NaN
# 11                                             ,ccat,          NaN
# 12                                  ,gnano,gcat,gsci,          NaN
# 13                   ,ccat,gspo,ncat,nfact,nfce,nrgn,          NaN
# 14                       ,cpartn,e1110,ccat,e11,ecat,          NaN
# 15                  ,ggolf,gspo,ncat,nfact,nfce,nrgn,          NaN
# 16                           ,gptech,ccat,gcat,glife,          NaN
# 17                  ,ccat,ccrm,c31,ncat,nfact,nfcpin,          NaN
# 18                          ,c133,ccat,cgymtr,cinprp,          NaN
# 19  ,c1512,c15,c151,cactio,ccat,ncat,nfact,nfce,nf...          NaN
#
#     modification_datetime                                               body  \
# 0           1489442488000  Those respondents with advanced full life cycl...
# 1           1487890959000  The Access Valve for ThingWorx integrates an o...
# 2           1508513602000  Cortana on the new speaker will look up inform...
# 3           1484229727000  According to Lee Nagel, vice president of mark...
# 4           1503007605000  Given its aggressive plans to take more market...
# 5           1504044122000  Reporters obtained the following quote from th...
# 6           1501603419000  Werner, as it happened, knew quite a bit about...
# 7           1487995921000  What happened\n\nShares of Hewlett Packard Ent...
# 8           1486681382000  This patent was filed on October 12, 2015 and ...
# 9           1499778788000  Developed in partnership with the Infor Custom...
# 10          1485519679000  Ed Bushey co-Publisher of Newsday said, Were i...
# 11          1499465861000  Prescriptive analytics is a breakthrough form ...
# 12          1496383839000  Through its NanoLab, IBM is the first company ...
# 13          1497969613000  Experts point to several reasons behind the sl...
# 14          1506637464000  Bushel is the grain industry's first automated...
# 15          1506637527000  Eds: Updates.\n\nSam Saunders, Arnold Palmer's...
# 16          1514427126000  “We’re in limited beta as of Christmas Day & a...
# 17          1490738981000  Under the terms of the agreement, BBVA will de...
# 18          1513897347000  Reporters obtained the following quote from th...
# 19          1488960132000  The American Health Care Act would, among othe...
#
#     company_codes_occur_ticker_exchange  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
#
#                                   company_codes_occur  \
# 0                                            ,comasc,
# 1                                                 NaN
# 2                ,mcrost,harmki,gognew,bstbuy,amzcom,
# 3                               ,orncmi,onlnfr,linkd,
# 4                                            ,hubspo,
# 5                                            ,arhvni,
# 6   ,twnit,secws,rclicl,pgxxrc,mcrost,fnbo,fdatc,f...
# 7                                            ,hpntrz,
# 8                                            ,ascntv,
# 9                                            ,agilis,
# 10                             ,zxamaz,tribmn,saxden,
# 11                                     ,prwth,mcrost,
# 12                                              ,ibm,
# 13                              ,ubisft,snyco,elarts,
# 14                                           ,qbeibp,
# 15                                                NaN
# 16                                                NaN
# 17                                     ,fnrlir,banbv,
# 18                                           ,emdebs,
# 19                                                NaN
#
#               company_codes_about company_codes_lineage  ...  company_name_2  \
# 0                        ,comasc,                   NaN  ...            None
# 1                             NaN                   NaN  ...            None
# 2   ,mcrost,harint,bstbuy,harmki,              ,sansel,  ...          harint
# 3                             NaN                   NaN  ...           linkd
# 4                        ,hubspo,                   NaN  ...          hubspo
# 5                        ,arhvni,                   NaN  ...            None
# 6                  ,fbinv,pgxxrc,                   NaN  ...           secws
# 7                 ,mtlyfo,hpntrz,                   NaN  ...          hpntrz
# 8                             NaN                   NaN  ...            None
# 9                        ,agilis,                   NaN  ...            None
# 10         ,zxamaz,tribmn,saxden,       ,visepl,amzcom,  ...          visepl
# 11                       ,mcrost,                   NaN  ...          mdeviu
# 12                   ,ibm,ufdmgu,                   NaN  ...          ufdmgu
# 13                            NaN                   NaN  ...           snyco
# 14                            NaN                   NaN  ...            None
# 15                       ,ellmae,                   NaN  ...            None
# 16                         ,goog,                   NaN  ...            None
# 17                 ,banbv,fnrlir,                   NaN  ...           banbv
# 18                       ,emdebs,              ,blgrou,  ...          emdebs
# 19                       ,crnwrl,                   NaN  ...            None
#
#    company_name_3  company_name_4  company_name_5 company_name_6  \
# 0            None            None            None           None
# 1            None            None            None           None
# 2          bstbuy          mcrost          harmki         sansel
# 3           twnit          onlnfr            None           None
# 4            None            None            None           None
# 5            None            None            None           None
# 6          rclicl           fdatc           fbinv         mcrost
# 7          uniowm          mtlyfo            None           None
# 8            None            None            None           None
# 9            None            None            None           None
# 10         tribmn          saxden          zxamaz           None
# 11          prwth            None            None           None
# 12           None            None            None           None
# 13         ubisft            None            None           None
# 14           None            None            None           None
# 15           None            None            None           None
# 16           None            None            None           None
# 17           None            None            None           None
# 18           None            None            None           None
# 19           None            None            None           None
#
#    company_name_7 company_name_8  company_name_9 company_name_10  \
# 0            None           None            None            None
# 1            None           None            None            None
# 2          gognew           None            None            None
# 3            None           None            None            None
# 4            None           None            None            None
# 5            None           None            None            None
# 6           twnit           soca          usddhs          pgxxrc
# 7            None           None            None            None
# 8            None           None            None            None
# 9            None           None            None            None
# 10           None           None            None            None
# 11           None           None            None            None
# 12           None           None            None            None
# 13           None           None            None            None
# 14           None           None            None            None
# 15           None           None            None            None
# 16           None           None            None            None
# 17           None           None            None            None
# 18           None           None            None            None
# 19           None           None            None            None
#
#     company_name_11
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6            usagov
# 7              None
# 8              None
# 9              None
# 10             None
# 11             None
# 12             None
# 13             None
# 14             None
# 15             None
# 16             None
# 17             None
# 18             None
# 19             None
#
# [20 rows x 56 columns]

# %%
# Out:
#    company_name_1 company_name_2 company_name_3 company_name_4 company_name_5  \
# 0          comasc           None           None           None           None
# 1            None           None           None           None           None
# 2          amzcom         harint         bstbuy         mcrost         harmki
# 3          orncmi          linkd          twnit         onlnfr           None
# 4          salesf         hubspo           None           None           None
# 5          arhvni           None           None           None           None
# 6            fnbo          secws         rclicl          fdatc          fbinv
# 7          cmptsn         hpntrz         uniowm         mtlyfo           None
# 8          ascntv           None           None           None           None
# 9          agilis           None           None           None           None
# 10         amzcom         visepl         tribmn         saxden         zxamaz
# 11         mcrost         mdeviu          prwth           None           None
# 12            ibm         ufdmgu           None           None           None
# 13         elarts          snyco         ubisft           None           None
# 14         qbeibp           None           None           None           None
# 15         ellmae           None           None           None           None
# 16           goog           None           None           None           None
# 17         fnrlir          banbv           None           None           None
# 18         blgrou         emdebs           None           None           None
# 19         crnwrl           None           None           None           None
#
#    company_name_6 company_name_7 company_name_8 company_name_9  \
# 0            None           None           None           None
# 1            None           None           None           None
# 2          sansel         gognew           None           None
# 3            None           None           None           None
# 4            None           None           None           None
# 5            None           None           None           None
# 6          mcrost          twnit           soca         usddhs
# 7            None           None           None           None
# 8            None           None           None           None
# 9            None           None           None           None
# 10           None           None           None           None
# 11           None           None           None           None
# 12           None           None           None           None
# 13           None           None           None           None
# 14           None           None           None           None
# 15           None           None           None           None
# 16           None           None           None           None
# 17           None           None           None           None
# 18           None           None           None           None
# 19           None           None           None           None
#
#    company_name_10 company_name_11
# 0             None            None
# 1             None            None
# 2             None            None
# 3             None            None
# 4             None            None
# 5             None            None
# 6           pgxxrc          usagov
# 7             None            None
# 8             None            None
# 9             None            None
# 10            None            None
# 11            None            None
# 12            None            None
# 13            None            None
# 14            None            None
# 15            None            None
# 16            None            None
# 17            None            None
# 18            None            None
# 19            None            None

# %%
list_of_companies
# Out:
# ['company_name_0',
#  'company_name_1',
#  'company_name_2',
#  'company_name_3',
#  'company_name_4',
#  'company_name_5',
#  'company_name_6',
#  'company_name_7',
#  'company_name_8',
#  'company_name_9',
#  'company_name_10']

# %%
list_of_column_labels

# %%
df_new.company_codes.replace([], np.NaN)
# Out:
# 0                                              [comasc]
# 1                                                    []
# 2     [amzcom, harint, bstbuy, mcrost, harmki, sanse...
# 3                        [orncmi, linkd, twnit, onlnfr]
# 4                                      [salesf, hubspo]
# 5                                              [arhvni]
# 6     [fnbo, secws, rclicl, fdatc, fbinv, mcrost, tw...
# 7                      [cmptsn, hpntrz, uniowm, mtlyfo]
# 8                                              [ascntv]
# 9                                              [agilis]
# 10             [amzcom, visepl, tribmn, saxden, zxamaz]
# 11                              [mcrost, mdeviu, prwth]
# 12                                        [ibm, ufdmgu]
# 13                              [elarts, snyco, ubisft]
# 14                                             [qbeibp]
# 15                                             [ellmae]
# 16                                               [goog]
# 17                                      [fnrlir, banbv]
# 18                                     [blgrou, emdebs]
# 19                                             [crnwrl]
# Name: company_codes, dtype: object

# %%
for i in range(len(df_new)):
    print(df_new.loc[i, "company_codes"])
# Out:
# comasc
#
# ['harmki', 'amzcom', 'amzcom', 'bstbuy', 'bstbuy', 'gognew', 'gognew', 'harmki', 'harmki', 'mcrost', 'mcrost', 'bstbuy', 'harint', 'mcrost', 'sansel']
# ['linkd', 'linkd', 'onlnfr', 'onlnfr', 'orncmi', 'orncmi', 'twnit']
# ['hubspo', 'hubspo', 'hubspo', 'salesf']
# ['arhvni', 'arhvni', 'arhvni']
# ['pgxxrc', 'fbinv', 'fbinv', 'fdatc', 'fdatc', 'fnbo', 'fnbo', 'mcrost', 'mcrost', 'pgxxrc', 'pgxxrc', 'rclicl', 'rclicl', 'secws', 'secws', 'soca', 'twnit', 'twnit', 'usagov', 'usddhs', 'fbinv']
# ['cmptsn', 'hpntrz', 'hpntrz', 'mtlyfo', 'uniowm', 'hpntrz', 'mtlyfo']
# ['ascntv', 'ascntv']
# ['agilis', 'agilis', 'agilis']
# ['saxden', 'tribmn', 'zxamaz', 'saxden', 'saxden', 'tribmn', 'tribmn', 'zxamaz', 'zxamaz', 'amzcom', 'visepl']
# ['mcrost', 'mcrost', 'mdeviu', 'prwth', 'prwth', 'mcrost']
# ['ufdmgu', 'ibm', 'ibm', 'ufdmgu', 'ibm']
# ['elarts', 'elarts', 'snyco', 'snyco', 'ubisft', 'ubisft']
# ['qbeibp', 'qbeibp']
# ['ellmae', 'ellmae']
# ['goog']
# ['fnrlir', 'banbv', 'banbv', 'fnrlir', 'fnrlir', 'banbv']
# ['emdebs', 'emdebs', 'emdebs', 'blgrou']
# ['crnwrl']

# %%
df_new
# Out:
#     index                                          copyright  \
# 0      15  © Copyright 2017 Journal of Engineering via Ve...
# 1      18  © Copyright 2017 Computer Weekly News via via ...
# 2      26  Copyright 2017 Telecompaper. All Rights Reserv...
# 3      36  © Copyright 2017 GlobeNewswire, Inc. All Right...
# 4      57  © Copyright 2017 Computer Weekly News via via ...
# 5      78  © Copyright 2017 Information Technology Newswe...
# 6     107           © 2017 Condé Nast. All rights reserved.
# 7     124   © 2017, M2 Communications. All rights reserved.
# 8     125  © Copyright 2017 Computer Weekly News via via ...
# 9     142   © 2017, M2 Communications. All rights reserved.
# 10    145  © 2017, Namibian Sun, All rights Reserved - Pr...
# 11    180  © Copyright 2017 Marketing Weekly News via Ver...
# 12    198  © 2017, Ventures Africa, All rights Reserved -...
# 13    218  Copyright 2017 Northwest Herald, The (Crystal ...
# 14    226  © Copyright 2017 Agriculture Week via NewsRx.com
# 15    232  (c) 2017.  The Associated Press.  All Rights R...
# 16    253  © 2017 American City Business Journals, Inc. A...
# 17    278  © Copyright 2017 Information Technology Newswe...
# 18    285  © Copyright 2017 Computer Weekly News via via ...
# 19    289                      © 2017, Herald & Times Group
#
#                                         subject_codes          art  \
# 0                                              ,ccat,          NaN
# 1                                              ,ccat,          NaN
# 2             ,ccat,c22,cprdop,c24,ncat,nfact,nfcpin,          NaN
# 3                ,cpartn,ccpint,npress,c11,ccat,ncat,          NaN
# 4                                              ,ccat,          NaN
# 5                           ,c133,ccat,cgymtr,cinprp,          NaN
# 6   ,gcvir,gdip,ghack,gspy,gcat,gcns,gcrim,gpir,nc...  CHAD HAGEN
# 7                                    ,guni,gcat,gedu,          NaN
# 8               ,c133,gdatap,ccat,cgymtr,cinprp,gcat,          NaN
# 9   ,cpartn,ccexpi,ccrm,npress,c31,ccat,ncat,nfact...          NaN
# 10                  ,c314,c31,ccat,ncat,nfact,nfcpin,          NaN
# 11                                             ,ccat,          NaN
# 12                                  ,gnano,gcat,gsci,          NaN
# 13                   ,ccat,gspo,ncat,nfact,nfce,nrgn,          NaN
# 14                       ,cpartn,e1110,ccat,e11,ecat,          NaN
# 15                  ,ggolf,gspo,ncat,nfact,nfce,nrgn,          NaN
# 16                           ,gptech,ccat,gcat,glife,          NaN
# 17                  ,ccat,ccrm,c31,ncat,nfact,nfcpin,          NaN
# 18                          ,c133,ccat,cgymtr,cinprp,          NaN
# 19  ,c1512,c15,c151,cactio,ccat,ncat,nfact,nfce,nf...          NaN
#
#     modification_datetime                                               body  \
# 0           1489442488000  Those respondents with advanced full life cycl...
# 1           1487890959000  The Access Valve for ThingWorx integrates an o...
# 2           1508513602000  Cortana on the new speaker will look up inform...
# 3           1484229727000  According to Lee Nagel, vice president of mark...
# 4           1503007605000  Given its aggressive plans to take more market...
# 5           1504044122000  Reporters obtained the following quote from th...
# 6           1501603419000  Werner, as it happened, knew quite a bit about...
# 7           1487995921000  What happened\n\nShares of Hewlett Packard Ent...
# 8           1486681382000  This patent was filed on October 12, 2015 and ...
# 9           1499778788000  Developed in partnership with the Infor Custom...
# 10          1485519679000  Ed Bushey co-Publisher of Newsday said, Were i...
# 11          1499465861000  Prescriptive analytics is a breakthrough form ...
# 12          1496383839000  Through its NanoLab, IBM is the first company ...
# 13          1497969613000  Experts point to several reasons behind the sl...
# 14          1506637464000  Bushel is the grain industry's first automated...
# 15          1506637527000  Eds: Updates.\n\nSam Saunders, Arnold Palmer's...
# 16          1514427126000  “We’re in limited beta as of Christmas Day & a...
# 17          1490738981000  Under the terms of the agreement, BBVA will de...
# 18          1513897347000  Reporters obtained the following quote from th...
# 19          1488960132000  The American Health Care Act would, among othe...
#
#     company_codes_occur_ticker_exchange  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
#
#                                   company_codes_occur  \
# 0                                            ,comasc,
# 1                                                 NaN
# 2                ,mcrost,harmki,gognew,bstbuy,amzcom,
# 3                               ,orncmi,onlnfr,linkd,
# 4                                            ,hubspo,
# 5                                            ,arhvni,
# 6   ,twnit,secws,rclicl,pgxxrc,mcrost,fnbo,fdatc,f...
# 7                                            ,hpntrz,
# 8                                            ,ascntv,
# 9                                            ,agilis,
# 10                             ,zxamaz,tribmn,saxden,
# 11                                     ,prwth,mcrost,
# 12                                              ,ibm,
# 13                              ,ubisft,snyco,elarts,
# 14                                           ,qbeibp,
# 15                                                NaN
# 16                                                NaN
# 17                                     ,fnrlir,banbv,
# 18                                           ,emdebs,
# 19                                                NaN
#
#               company_codes_about company_codes_lineage  ...  \
# 0                        ,comasc,                   NaN  ...
# 1                             NaN                   NaN  ...
# 2   ,mcrost,harint,bstbuy,harmki,              ,sansel,  ...
# 3                             NaN                   NaN  ...
# 4                        ,hubspo,                   NaN  ...
# 5                        ,arhvni,                   NaN  ...
# 6                  ,fbinv,pgxxrc,                   NaN  ...
# 7                 ,mtlyfo,hpntrz,                   NaN  ...
# 8                             NaN                   NaN  ...
# 9                        ,agilis,                   NaN  ...
# 10         ,zxamaz,tribmn,saxden,       ,visepl,amzcom,  ...
# 11                       ,mcrost,                   NaN  ...
# 12                   ,ibm,ufdmgu,                   NaN  ...
# 13                            NaN                   NaN  ...
# 14                            NaN                   NaN  ...
# 15                       ,ellmae,                   NaN  ...
# 16                         ,goog,                   NaN  ...
# 17                 ,banbv,fnrlir,                   NaN  ...
# 18                       ,emdebs,              ,blgrou,  ...
# 19                       ,crnwrl,                   NaN  ...
#
#                                         company_codes  \
# 0                                              comasc
# 1
# 2   [harmki, amzcom, amzcom, bstbuy, bstbuy, gogne...
# 3   [linkd, linkd, onlnfr, onlnfr, orncmi, orncmi,...
# 4                    [hubspo, hubspo, hubspo, salesf]
# 5                            [arhvni, arhvni, arhvni]
# 6   [pgxxrc, fbinv, fbinv, fdatc, fdatc, fnbo, fnb...
# 7   [cmptsn, hpntrz, hpntrz, mtlyfo, uniowm, hpntr...
# 8                                    [ascntv, ascntv]
# 9                            [agilis, agilis, agilis]
# 10  [saxden, tribmn, zxamaz, saxden, saxden, tribm...
# 11     [mcrost, mcrost, mdeviu, prwth, prwth, mcrost]
# 12                    [ufdmgu, ibm, ibm, ufdmgu, ibm]
# 13     [elarts, elarts, snyco, snyco, ubisft, ubisft]
# 14                                   [qbeibp, qbeibp]
# 15                                   [ellmae, ellmae]
# 16                                             [goog]
# 17      [fnrlir, banbv, banbv, fnrlir, fnrlir, banbv]
# 18                   [emdebs, emdebs, emdebs, blgrou]
# 19                                           [crnwrl]
#
#                                        industry_codes  \
# 0       ,imobsoft,i3302,i330202,i3302021,icomp,itech,
# 1   ,isecpri,iioft,i3302,i330202,i3302021,i3303,ic...
# 2   ,i34532,i3302,icnp,idurhg,ielec,ihome,itech,i3...
# 3          ,ibisw,i3302021,i3302,i330202,icomp,itech,
# 4        ,icomp,i3302,itech,i330202,i3302021,ientrps,
# 5   ,i33031,i79022,i3302,i3303,i3441,i7902,ibrdbi,...
# 6   ,i814,ibnk,ifinal,i3302,i330202,i3302021,icomp...
# 7   ,i3302,i330202,i3302021,i831,i83108,icomp,ient...
# 8    ,ibrows,i3302,i330202,i3302021,icomp,iint,itech,
# 9        ,i3302,i330202,i3302021,icomp,ientrps,itech,
# 10  ,i3302,i330202,i3302021,i475,i8394,iappsp,ibcs...
# 11  ,iappsp,i8394,ibcs,i3302,i330202,i3302021,icom...
# 12  ,isimsft,i1300003,i1,i13,i3302,i330202,i330202...
# 13  ,igamsof,ivrealt,i3302,i330202,i3302021,icomp,...
# 14  ,i82,imobsoft,i3302,i330202,i3302021,icomp,ifi...
# 15               ,i3302,i330202,i3302021,icomp,itech,
# 16  ,imobsoft,i3302,i330202,i3302021,icomp,itech,i...
# 17  ,i3302021,i3302,i330202,icomp,itech,i814,ibnk,...
# 18       ,icomp,i3302,itech,i330202,i3302021,iknowms,
# 19  ,i8200301,i951,i82,i82003,ifinal,i3302,i330202...
#
#                                                 title  publication_datetime  \
# 0   CA Technologies; Are You Getting the Most Valu...         1489363200000
# 1   Certified Security Solutions, Inc. CSS Release...         1487808000000
# 2   Harman Kardon launches smart speaker with Micr...         1508457600000
# 3   Izenda Partners with Orion Communications to P...         1484229604057
# 4   Qstream; HubSpot Signs Global Agreement with Q...         1502928000000
# 5   Aerohive Networks, Inc. Patent Application Tit...         1503964800000
# 6   CHASING THE PHANTOM; A MYSTERIOUS RUSSIAN HACK...         1491004800000
# 7   Why Shares of Hewlett Packard Enterprise Dropp...         1487894400000
# 8   ASCENTIVE LLC; Patent Issued for System for Ne...         1486598400000
# 9   Infor Amplifies Customer Service by Delivering...         1499731200000
# 10  Newsday Selects NEWSCYCLE Solutions for Hosted...         1485475200000
# 11  River Logic, Inc. River Logic Quickly Fills Pr...         1499385600000
# 12  United States : IBM Leads Countrys First Nanot...         1496275200000
# 13  Why is virtual reality taking so long to take ...         1497830400000
# 14  Myriad Mobile; Bushel(TM) Launches Ecosystem w...         1506556800000
# 15        BC-GLF--Webcom-Saunders-59,2nd Ld-Writethru         1506637438677
# 16   Android users will get HQ Trivia app by new year         1514419200000
# 17  Fenergo; Fenergo Signs First Spanish Banking C...         1490659200000
# 18  Medical Records; Patent Issued for Fault Toler...         1513814400000
# 19       Software firm not fazed by US health reforms         1488931200000
#
#                                        publisher_name action document_type  \
# 0                                         NewsRX, LLC    add       article
# 1                                         NewsRX, LLC    add       article
# 2                                     Telecompaper BV    add       article
# 3                                 GlobeNewswire, Inc.    add       article
# 4                                         NewsRX, LLC    add       article
# 5                                         NewsRX, LLC    add       article
# 6                                          Condé Nast    add       article
# 7                                   Normans Media Ltd    add       article
# 8                                         NewsRX, LLC    add       article
# 9                                   Normans Media Ltd    add       article
# 10                             Namibia Media Holdings    add       article
# 11                                        NewsRX, LLC    add       article
# 12                                    Ventures Africa    add       article
# 13                                         Shaw Media    add       article
# 14                                        NewsRX, LLC    add       article
# 15                               The Associated Press    add       article
# 16                    American City Business Journals    add       article
# 17                                        NewsRX, LLC    add       article
# 18                                        NewsRX, LLC    add       article
# 19  Newsquest (Herald and Times) LTD and Newsquest...    add       article
#
#                        date  year  \
# 0   2017-03-13 00:00:00.000  2017
# 1   2017-02-23 00:00:00.000  2017
# 2   2017-10-20 00:00:00.000  2017
# 3   2017-01-12 14:00:04.057  2017
# 4   2017-08-17 00:00:00.000  2017
# 5   2017-08-29 00:00:00.000  2017
# 6   2017-04-01 00:00:00.000  2017
# 7   2017-02-24 00:00:00.000  2017
# 8   2017-02-09 00:00:00.000  2017
# 9   2017-07-11 00:00:00.000  2017
# 10  2017-01-27 00:00:00.000  2017
# 11  2017-07-07 00:00:00.000  2017
# 12  2017-06-01 00:00:00.000  2017
# 13  2017-06-19 00:00:00.000  2017
# 14  2017-09-28 00:00:00.000  2017
# 15  2017-09-28 22:23:58.677  2017
# 16  2017-12-28 00:00:00.000  2017
# 17  2017-03-28 00:00:00.000  2017
# 18  2017-12-21 00:00:00.000  2017
# 19  2017-03-08 00:00:00.000  2017
#
#                                             full_text
# 0   CA Technologies; Are You Getting the Most Valu...
# 1   Certified Security Solutions, Inc. CSS Release...
# 2   Harman Kardon launches smart speaker with Micr...
# 3   Izenda Partners with Orion Communications to P...
# 4   Qstream; HubSpot Signs Global Agreement with Q...
# 5   Aerohive Networks, Inc. Patent Application Tit...
# 6   CHASING THE PHANTOM; A MYSTERIOUS RUSSIAN HACK...
# 7   Why Shares of Hewlett Packard Enterprise Dropp...
# 8   ASCENTIVE LLC; Patent Issued for System for Ne...
# 9   Infor Amplifies Customer Service by Delivering...
# 10  Newsday Selects NEWSCYCLE Solutions for Hosted...
# 11  River Logic, Inc. River Logic Quickly Fills Pr...
# 12  United States : IBM Leads Countrys First Nanot...
# 13  Why is virtual reality taking so long to take ...
# 14  Myriad Mobile; Bushel(TM) Launches Ecosystem w...
# 15  BC-GLF--Webcom-Saunders-59,2nd Ld-Writethru BC...
# 16  Android users will get HQ Trivia app by new ye...
# 17  Fenergo; Fenergo Signs First Spanish Banking C...
# 18  Medical Records; Patent Issued for Fault Toler...
# 19  Software firm not fazed by US health reforms C...
#
# [20 rows x 45 columns]

# %%
df_new
# Out:
#     index                                          copyright  \
# 0      15  © Copyright 2017 Journal of Engineering via Ve...
# 1      18  © Copyright 2017 Computer Weekly News via via ...
# 2      26  Copyright 2017 Telecompaper. All Rights Reserv...
# 3      36  © Copyright 2017 GlobeNewswire, Inc. All Right...
# 4      57  © Copyright 2017 Computer Weekly News via via ...
# 5      78  © Copyright 2017 Information Technology Newswe...
# 6     107           © 2017 Condé Nast. All rights reserved.
# 7     124   © 2017, M2 Communications. All rights reserved.
# 8     125  © Copyright 2017 Computer Weekly News via via ...
# 9     142   © 2017, M2 Communications. All rights reserved.
# 10    145  © 2017, Namibian Sun, All rights Reserved - Pr...
# 11    180  © Copyright 2017 Marketing Weekly News via Ver...
# 12    198  © 2017, Ventures Africa, All rights Reserved -...
# 13    218  Copyright 2017 Northwest Herald, The (Crystal ...
# 14    226  © Copyright 2017 Agriculture Week via NewsRx.com
# 15    232  (c) 2017.  The Associated Press.  All Rights R...
# 16    253  © 2017 American City Business Journals, Inc. A...
# 17    278  © Copyright 2017 Information Technology Newswe...
# 18    285  © Copyright 2017 Computer Weekly News via via ...
# 19    289                      © 2017, Herald & Times Group
#
#                                         subject_codes          art  \
# 0                                              ,ccat,          NaN
# 1                                              ,ccat,          NaN
# 2             ,ccat,c22,cprdop,c24,ncat,nfact,nfcpin,          NaN
# 3                ,cpartn,ccpint,npress,c11,ccat,ncat,          NaN
# 4                                              ,ccat,          NaN
# 5                           ,c133,ccat,cgymtr,cinprp,          NaN
# 6   ,gcvir,gdip,ghack,gspy,gcat,gcns,gcrim,gpir,nc...  CHAD HAGEN
# 7                                    ,guni,gcat,gedu,          NaN
# 8               ,c133,gdatap,ccat,cgymtr,cinprp,gcat,          NaN
# 9   ,cpartn,ccexpi,ccrm,npress,c31,ccat,ncat,nfact...          NaN
# 10                  ,c314,c31,ccat,ncat,nfact,nfcpin,          NaN
# 11                                             ,ccat,          NaN
# 12                                  ,gnano,gcat,gsci,          NaN
# 13                   ,ccat,gspo,ncat,nfact,nfce,nrgn,          NaN
# 14                       ,cpartn,e1110,ccat,e11,ecat,          NaN
# 15                  ,ggolf,gspo,ncat,nfact,nfce,nrgn,          NaN
# 16                           ,gptech,ccat,gcat,glife,          NaN
# 17                  ,ccat,ccrm,c31,ncat,nfact,nfcpin,          NaN
# 18                          ,c133,ccat,cgymtr,cinprp,          NaN
# 19  ,c1512,c15,c151,cactio,ccat,ncat,nfact,nfce,nf...          NaN
#
#     modification_datetime                                               body  \
# 0           1489442488000  Those respondents with advanced full life cycl...
# 1           1487890959000  The Access Valve for ThingWorx integrates an o...
# 2           1508513602000  Cortana on the new speaker will look up inform...
# 3           1484229727000  According to Lee Nagel, vice president of mark...
# 4           1503007605000  Given its aggressive plans to take more market...
# 5           1504044122000  Reporters obtained the following quote from th...
# 6           1501603419000  Werner, as it happened, knew quite a bit about...
# 7           1487995921000  What happened\n\nShares of Hewlett Packard Ent...
# 8           1486681382000  This patent was filed on October 12, 2015 and ...
# 9           1499778788000  Developed in partnership with the Infor Custom...
# 10          1485519679000  Ed Bushey co-Publisher of Newsday said, Were i...
# 11          1499465861000  Prescriptive analytics is a breakthrough form ...
# 12          1496383839000  Through its NanoLab, IBM is the first company ...
# 13          1497969613000  Experts point to several reasons behind the sl...
# 14          1506637464000  Bushel is the grain industry's first automated...
# 15          1506637527000  Eds: Updates.\n\nSam Saunders, Arnold Palmer's...
# 16          1514427126000  “We’re in limited beta as of Christmas Day & a...
# 17          1490738981000  Under the terms of the agreement, BBVA will de...
# 18          1513897347000  Reporters obtained the following quote from th...
# 19          1488960132000  The American Health Care Act would, among othe...
#
#     company_codes_occur_ticker_exchange  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
#
#                                   company_codes_occur  \
# 0                                            ,comasc,
# 1                                                 NaN
# 2                ,mcrost,harmki,gognew,bstbuy,amzcom,
# 3                               ,orncmi,onlnfr,linkd,
# 4                                            ,hubspo,
# 5                                            ,arhvni,
# 6   ,twnit,secws,rclicl,pgxxrc,mcrost,fnbo,fdatc,f...
# 7                                            ,hpntrz,
# 8                                            ,ascntv,
# 9                                            ,agilis,
# 10                             ,zxamaz,tribmn,saxden,
# 11                                     ,prwth,mcrost,
# 12                                              ,ibm,
# 13                              ,ubisft,snyco,elarts,
# 14                                           ,qbeibp,
# 15                                                NaN
# 16                                                NaN
# 17                                     ,fnrlir,banbv,
# 18                                           ,emdebs,
# 19                                                NaN
#
#               company_codes_about company_codes_lineage  ...  \
# 0                        ,comasc,                   NaN  ...
# 1                             NaN                   NaN  ...
# 2   ,mcrost,harint,bstbuy,harmki,              ,sansel,  ...
# 3                             NaN                   NaN  ...
# 4                        ,hubspo,                   NaN  ...
# 5                        ,arhvni,                   NaN  ...
# 6                  ,fbinv,pgxxrc,                   NaN  ...
# 7                 ,mtlyfo,hpntrz,                   NaN  ...
# 8                             NaN                   NaN  ...
# 9                        ,agilis,                   NaN  ...
# 10         ,zxamaz,tribmn,saxden,       ,visepl,amzcom,  ...
# 11                       ,mcrost,                   NaN  ...
# 12                   ,ibm,ufdmgu,                   NaN  ...
# 13                            NaN                   NaN  ...
# 14                            NaN                   NaN  ...
# 15                       ,ellmae,                   NaN  ...
# 16                         ,goog,                   NaN  ...
# 17                 ,banbv,fnrlir,                   NaN  ...
# 18                       ,emdebs,              ,blgrou,  ...
# 19                       ,crnwrl,                   NaN  ...
#
#                                         company_codes  \
# 0                            [comasc, comasc, comasc]
# 1                                                 NaN
# 2   [harmki, amzcom, amzcom, bstbuy, bstbuy, gogne...
# 3   [linkd, linkd, onlnfr, onlnfr, orncmi, orncmi,...
# 4                    [hubspo, hubspo, hubspo, salesf]
# 5                            [arhvni, arhvni, arhvni]
# 6   [pgxxrc, fbinv, fbinv, fdatc, fdatc, fnbo, fnb...
# 7   [cmptsn, hpntrz, hpntrz, mtlyfo, uniowm, hpntr...
# 8                                    [ascntv, ascntv]
# 9                            [agilis, agilis, agilis]
# 10  [saxden, tribmn, zxamaz, saxden, saxden, tribm...
# 11     [mcrost, mcrost, mdeviu, prwth, prwth, mcrost]
# 12                    [ufdmgu, ibm, ibm, ufdmgu, ibm]
# 13     [elarts, elarts, snyco, snyco, ubisft, ubisft]
# 14                                   [qbeibp, qbeibp]
# 15                                   [ellmae, ellmae]
# 16                                             [goog]
# 17      [fnrlir, banbv, banbv, fnrlir, fnrlir, banbv]
# 18                   [emdebs, emdebs, emdebs, blgrou]
# 19                                           [crnwrl]
#
#                                        industry_codes  \
# 0       ,imobsoft,i3302,i330202,i3302021,icomp,itech,
# 1   ,isecpri,iioft,i3302,i330202,i3302021,i3303,ic...
# 2   ,i34532,i3302,icnp,idurhg,ielec,ihome,itech,i3...
# 3          ,ibisw,i3302021,i3302,i330202,icomp,itech,
# 4        ,icomp,i3302,itech,i330202,i3302021,ientrps,
# 5   ,i33031,i79022,i3302,i3303,i3441,i7902,ibrdbi,...
# 6   ,i814,ibnk,ifinal,i3302,i330202,i3302021,icomp...
# 7   ,i3302,i330202,i3302021,i831,i83108,icomp,ient...
# 8    ,ibrows,i3302,i330202,i3302021,icomp,iint,itech,
# 9        ,i3302,i330202,i3302021,icomp,ientrps,itech,
# 10  ,i3302,i330202,i3302021,i475,i8394,iappsp,ibcs...
# 11  ,iappsp,i8394,ibcs,i3302,i330202,i3302021,icom...
# 12  ,isimsft,i1300003,i1,i13,i3302,i330202,i330202...
# 13  ,igamsof,ivrealt,i3302,i330202,i3302021,icomp,...
# 14  ,i82,imobsoft,i3302,i330202,i3302021,icomp,ifi...
# 15               ,i3302,i330202,i3302021,icomp,itech,
# 16  ,imobsoft,i3302,i330202,i3302021,icomp,itech,i...
# 17  ,i3302021,i3302,i330202,icomp,itech,i814,ibnk,...
# 18       ,icomp,i3302,itech,i330202,i3302021,iknowms,
# 19  ,i8200301,i951,i82,i82003,ifinal,i3302,i330202...
#
#                                                 title  publication_datetime  \
# 0   CA Technologies; Are You Getting the Most Valu...         1489363200000
# 1   Certified Security Solutions, Inc. CSS Release...         1487808000000
# 2   Harman Kardon launches smart speaker with Micr...         1508457600000
# 3   Izenda Partners with Orion Communications to P...         1484229604057
# 4   Qstream; HubSpot Signs Global Agreement with Q...         1502928000000
# 5   Aerohive Networks, Inc. Patent Application Tit...         1503964800000
# 6   CHASING THE PHANTOM; A MYSTERIOUS RUSSIAN HACK...         1491004800000
# 7   Why Shares of Hewlett Packard Enterprise Dropp...         1487894400000
# 8   ASCENTIVE LLC; Patent Issued for System for Ne...         1486598400000
# 9   Infor Amplifies Customer Service by Delivering...         1499731200000
# 10  Newsday Selects NEWSCYCLE Solutions for Hosted...         1485475200000
# 11  River Logic, Inc. River Logic Quickly Fills Pr...         1499385600000
# 12  United States : IBM Leads Countrys First Nanot...         1496275200000
# 13  Why is virtual reality taking so long to take ...         1497830400000
# 14  Myriad Mobile; Bushel(TM) Launches Ecosystem w...         1506556800000
# 15        BC-GLF--Webcom-Saunders-59,2nd Ld-Writethru         1506637438677
# 16   Android users will get HQ Trivia app by new year         1514419200000
# 17  Fenergo; Fenergo Signs First Spanish Banking C...         1490659200000
# 18  Medical Records; Patent Issued for Fault Toler...         1513814400000
# 19       Software firm not fazed by US health reforms         1488931200000
#
#                                        publisher_name action document_type  \
# 0                                         NewsRX, LLC    add       article
# 1                                         NewsRX, LLC    add       article
# 2                                     Telecompaper BV    add       article
# 3                                 GlobeNewswire, Inc.    add       article
# 4                                         NewsRX, LLC    add       article
# 5                                         NewsRX, LLC    add       article
# 6                                          Condé Nast    add       article
# 7                                   Normans Media Ltd    add       article
# 8                                         NewsRX, LLC    add       article
# 9                                   Normans Media Ltd    add       article
# 10                             Namibia Media Holdings    add       article
# 11                                        NewsRX, LLC    add       article
# 12                                    Ventures Africa    add       article
# 13                                         Shaw Media    add       article
# 14                                        NewsRX, LLC    add       article
# 15                               The Associated Press    add       article
# 16                    American City Business Journals    add       article
# 17                                        NewsRX, LLC    add       article
# 18                                        NewsRX, LLC    add       article
# 19  Newsquest (Herald and Times) LTD and Newsquest...    add       article
#
#                        date  year  \
# 0   2017-03-13 00:00:00.000  2017
# 1   2017-02-23 00:00:00.000  2017
# 2   2017-10-20 00:00:00.000  2017
# 3   2017-01-12 14:00:04.057  2017
# 4   2017-08-17 00:00:00.000  2017
# 5   2017-08-29 00:00:00.000  2017
# 6   2017-04-01 00:00:00.000  2017
# 7   2017-02-24 00:00:00.000  2017
# 8   2017-02-09 00:00:00.000  2017
# 9   2017-07-11 00:00:00.000  2017
# 10  2017-01-27 00:00:00.000  2017
# 11  2017-07-07 00:00:00.000  2017
# 12  2017-06-01 00:00:00.000  2017
# 13  2017-06-19 00:00:00.000  2017
# 14  2017-09-28 00:00:00.000  2017
# 15  2017-09-28 22:23:58.677  2017
# 16  2017-12-28 00:00:00.000  2017
# 17  2017-03-28 00:00:00.000  2017
# 18  2017-12-21 00:00:00.000  2017
# 19  2017-03-08 00:00:00.000  2017
#
#                                             full_text
# 0   CA Technologies; Are You Getting the Most Valu...
# 1   Certified Security Solutions, Inc. CSS Release...
# 2   Harman Kardon launches smart speaker with Micr...
# 3   Izenda Partners with Orion Communications to P...
# 4   Qstream; HubSpot Signs Global Agreement with Q...
# 5   Aerohive Networks, Inc. Patent Application Tit...
# 6   CHASING THE PHANTOM; A MYSTERIOUS RUSSIAN HACK...
# 7   Why Shares of Hewlett Packard Enterprise Dropp...
# 8   ASCENTIVE LLC; Patent Issued for System for Ne...
# 9   Infor Amplifies Customer Service by Delivering...
# 10  Newsday Selects NEWSCYCLE Solutions for Hosted...
# 11  River Logic, Inc. River Logic Quickly Fills Pr...
# 12  United States : IBM Leads Countrys First Nanot...
# 13  Why is virtual reality taking so long to take ...
# 14  Myriad Mobile; Bushel(TM) Launches Ecosystem w...
# 15  BC-GLF--Webcom-Saunders-59,2nd Ld-Writethru BC...
# 16  Android users will get HQ Trivia app by new ye...
# 17  Fenergo; Fenergo Signs First Spanish Banking C...
# 18  Medical Records; Patent Issued for Fault Toler...
# 19  Software firm not fazed by US health reforms C...
#
# [20 rows x 45 columns]

# %%
df_new
# Out:
#     index                                          copyright  \
# 0      15  © Copyright 2017 Journal of Engineering via Ve...
# 1      18  © Copyright 2017 Computer Weekly News via via ...
# 2      26  Copyright 2017 Telecompaper. All Rights Reserv...
# 3      36  © Copyright 2017 GlobeNewswire, Inc. All Right...
# 4      57  © Copyright 2017 Computer Weekly News via via ...
# 5      78  © Copyright 2017 Information Technology Newswe...
# 6     107           © 2017 Condé Nast. All rights reserved.
# 7     124   © 2017, M2 Communications. All rights reserved.
# 8     125  © Copyright 2017 Computer Weekly News via via ...
# 9     142   © 2017, M2 Communications. All rights reserved.
# 10    145  © 2017, Namibian Sun, All rights Reserved - Pr...
# 11    180  © Copyright 2017 Marketing Weekly News via Ver...
# 12    198  © 2017, Ventures Africa, All rights Reserved -...
# 13    218  Copyright 2017 Northwest Herald, The (Crystal ...
# 14    226  © Copyright 2017 Agriculture Week via NewsRx.com
# 15    232  (c) 2017.  The Associated Press.  All Rights R...
# 16    253  © 2017 American City Business Journals, Inc. A...
# 17    278  © Copyright 2017 Information Technology Newswe...
# 18    285  © Copyright 2017 Computer Weekly News via via ...
# 19    289                      © 2017, Herald & Times Group
#
#                                         subject_codes          art  \
# 0                                              ,ccat,          NaN
# 1                                              ,ccat,          NaN
# 2             ,ccat,c22,cprdop,c24,ncat,nfact,nfcpin,          NaN
# 3                ,cpartn,ccpint,npress,c11,ccat,ncat,          NaN
# 4                                              ,ccat,          NaN
# 5                           ,c133,ccat,cgymtr,cinprp,          NaN
# 6   ,gcvir,gdip,ghack,gspy,gcat,gcns,gcrim,gpir,nc...  CHAD HAGEN
# 7                                    ,guni,gcat,gedu,          NaN
# 8               ,c133,gdatap,ccat,cgymtr,cinprp,gcat,          NaN
# 9   ,cpartn,ccexpi,ccrm,npress,c31,ccat,ncat,nfact...          NaN
# 10                  ,c314,c31,ccat,ncat,nfact,nfcpin,          NaN
# 11                                             ,ccat,          NaN
# 12                                  ,gnano,gcat,gsci,          NaN
# 13                   ,ccat,gspo,ncat,nfact,nfce,nrgn,          NaN
# 14                       ,cpartn,e1110,ccat,e11,ecat,          NaN
# 15                  ,ggolf,gspo,ncat,nfact,nfce,nrgn,          NaN
# 16                           ,gptech,ccat,gcat,glife,          NaN
# 17                  ,ccat,ccrm,c31,ncat,nfact,nfcpin,          NaN
# 18                          ,c133,ccat,cgymtr,cinprp,          NaN
# 19  ,c1512,c15,c151,cactio,ccat,ncat,nfact,nfce,nf...          NaN
#
#     modification_datetime                                               body  \
# 0           1489442488000  Those respondents with advanced full life cycl...
# 1           1487890959000  The Access Valve for ThingWorx integrates an o...
# 2           1508513602000  Cortana on the new speaker will look up inform...
# 3           1484229727000  According to Lee Nagel, vice president of mark...
# 4           1503007605000  Given its aggressive plans to take more market...
# 5           1504044122000  Reporters obtained the following quote from th...
# 6           1501603419000  Werner, as it happened, knew quite a bit about...
# 7           1487995921000  What happened\n\nShares of Hewlett Packard Ent...
# 8           1486681382000  This patent was filed on October 12, 2015 and ...
# 9           1499778788000  Developed in partnership with the Infor Custom...
# 10          1485519679000  Ed Bushey co-Publisher of Newsday said, Were i...
# 11          1499465861000  Prescriptive analytics is a breakthrough form ...
# 12          1496383839000  Through its NanoLab, IBM is the first company ...
# 13          1497969613000  Experts point to several reasons behind the sl...
# 14          1506637464000  Bushel is the grain industry's first automated...
# 15          1506637527000  Eds: Updates.\n\nSam Saunders, Arnold Palmer's...
# 16          1514427126000  “We’re in limited beta as of Christmas Day & a...
# 17          1490738981000  Under the terms of the agreement, BBVA will de...
# 18          1513897347000  Reporters obtained the following quote from th...
# 19          1488960132000  The American Health Care Act would, among othe...
#
#     company_codes_occur_ticker_exchange  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
#
#                                   company_codes_occur  \
# 0                                            ,comasc,
# 1                                                 NaN
# 2                ,mcrost,harmki,gognew,bstbuy,amzcom,
# 3                               ,orncmi,onlnfr,linkd,
# 4                                            ,hubspo,
# 5                                            ,arhvni,
# 6   ,twnit,secws,rclicl,pgxxrc,mcrost,fnbo,fdatc,f...
# 7                                            ,hpntrz,
# 8                                            ,ascntv,
# 9                                            ,agilis,
# 10                             ,zxamaz,tribmn,saxden,
# 11                                     ,prwth,mcrost,
# 12                                              ,ibm,
# 13                              ,ubisft,snyco,elarts,
# 14                                           ,qbeibp,
# 15                                                NaN
# 16                                                NaN
# 17                                     ,fnrlir,banbv,
# 18                                           ,emdebs,
# 19                                                NaN
#
#               company_codes_about company_codes_lineage  ...  \
# 0                        ,comasc,                   NaN  ...
# 1                             NaN                   NaN  ...
# 2   ,mcrost,harint,bstbuy,harmki,              ,sansel,  ...
# 3                             NaN                   NaN  ...
# 4                        ,hubspo,                   NaN  ...
# 5                        ,arhvni,                   NaN  ...
# 6                  ,fbinv,pgxxrc,                   NaN  ...
# 7                 ,mtlyfo,hpntrz,                   NaN  ...
# 8                             NaN                   NaN  ...
# 9                        ,agilis,                   NaN  ...
# 10         ,zxamaz,tribmn,saxden,       ,visepl,amzcom,  ...
# 11                       ,mcrost,                   NaN  ...
# 12                   ,ibm,ufdmgu,                   NaN  ...
# 13                            NaN                   NaN  ...
# 14                            NaN                   NaN  ...
# 15                       ,ellmae,                   NaN  ...
# 16                         ,goog,                   NaN  ...
# 17                 ,banbv,fnrlir,                   NaN  ...
# 18                       ,emdebs,              ,blgrou,  ...
# 19                       ,crnwrl,                   NaN  ...
#
#                                         company_codes  \
# 0                            [comasc, comasc, comasc]
# 1                                                 NaN
# 2   [harmki, amzcom, amzcom, bstbuy, bstbuy, gogne...
# 3   [linkd, linkd, onlnfr, onlnfr, orncmi, orncmi,...
# 4                    [hubspo, hubspo, hubspo, salesf]
# 5                            [arhvni, arhvni, arhvni]
# 6   [pgxxrc, fbinv, fbinv, fdatc, fdatc, fnbo, fnb...
# 7   [cmptsn, hpntrz, hpntrz, mtlyfo, uniowm, hpntr...
# 8                                    [ascntv, ascntv]
# 9                            [agilis, agilis, agilis]
# 10  [saxden, tribmn, zxamaz, saxden, saxden, tribm...
# 11     [mcrost, mcrost, mdeviu, prwth, prwth, mcrost]
# 12                    [ufdmgu, ibm, ibm, ufdmgu, ibm]
# 13     [elarts, elarts, snyco, snyco, ubisft, ubisft]
# 14                                   [qbeibp, qbeibp]
# 15                                   [ellmae, ellmae]
# 16                                             [goog]
# 17      [fnrlir, banbv, banbv, fnrlir, fnrlir, banbv]
# 18                   [emdebs, emdebs, emdebs, blgrou]
# 19                                           [crnwrl]
#
#                                        industry_codes  \
# 0       ,imobsoft,i3302,i330202,i3302021,icomp,itech,
# 1   ,isecpri,iioft,i3302,i330202,i3302021,i3303,ic...
# 2   ,i34532,i3302,icnp,idurhg,ielec,ihome,itech,i3...
# 3          ,ibisw,i3302021,i3302,i330202,icomp,itech,
# 4        ,icomp,i3302,itech,i330202,i3302021,ientrps,
# 5   ,i33031,i79022,i3302,i3303,i3441,i7902,ibrdbi,...
# 6   ,i814,ibnk,ifinal,i3302,i330202,i3302021,icomp...
# 7   ,i3302,i330202,i3302021,i831,i83108,icomp,ient...
# 8    ,ibrows,i3302,i330202,i3302021,icomp,iint,itech,
# 9        ,i3302,i330202,i3302021,icomp,ientrps,itech,
# 10  ,i3302,i330202,i3302021,i475,i8394,iappsp,ibcs...
# 11  ,iappsp,i8394,ibcs,i3302,i330202,i3302021,icom...
# 12  ,isimsft,i1300003,i1,i13,i3302,i330202,i330202...
# 13  ,igamsof,ivrealt,i3302,i330202,i3302021,icomp,...
# 14  ,i82,imobsoft,i3302,i330202,i3302021,icomp,ifi...
# 15               ,i3302,i330202,i3302021,icomp,itech,
# 16  ,imobsoft,i3302,i330202,i3302021,icomp,itech,i...
# 17  ,i3302021,i3302,i330202,icomp,itech,i814,ibnk,...
# 18       ,icomp,i3302,itech,i330202,i3302021,iknowms,
# 19  ,i8200301,i951,i82,i82003,ifinal,i3302,i330202...
#
#                                                 title  publication_datetime  \
# 0   CA Technologies; Are You Getting the Most Valu...         1489363200000
# 1   Certified Security Solutions, Inc. CSS Release...         1487808000000
# 2   Harman Kardon launches smart speaker with Micr...         1508457600000
# 3   Izenda Partners with Orion Communications to P...         1484229604057
# 4   Qstream; HubSpot Signs Global Agreement with Q...         1502928000000
# 5   Aerohive Networks, Inc. Patent Application Tit...         1503964800000
# 6   CHASING THE PHANTOM; A MYSTERIOUS RUSSIAN HACK...         1491004800000
# 7   Why Shares of Hewlett Packard Enterprise Dropp...         1487894400000
# 8   ASCENTIVE LLC; Patent Issued for System for Ne...         1486598400000
# 9   Infor Amplifies Customer Service by Delivering...         1499731200000
# 10  Newsday Selects NEWSCYCLE Solutions for Hosted...         1485475200000
# 11  River Logic, Inc. River Logic Quickly Fills Pr...         1499385600000
# 12  United States : IBM Leads Countrys First Nanot...         1496275200000
# 13  Why is virtual reality taking so long to take ...         1497830400000
# 14  Myriad Mobile; Bushel(TM) Launches Ecosystem w...         1506556800000
# 15        BC-GLF--Webcom-Saunders-59,2nd Ld-Writethru         1506637438677
# 16   Android users will get HQ Trivia app by new year         1514419200000
# 17  Fenergo; Fenergo Signs First Spanish Banking C...         1490659200000
# 18  Medical Records; Patent Issued for Fault Toler...         1513814400000
# 19       Software firm not fazed by US health reforms         1488931200000
#
#                                        publisher_name action document_type  \
# 0                                         NewsRX, LLC    add       article
# 1                                         NewsRX, LLC    add       article
# 2                                     Telecompaper BV    add       article
# 3                                 GlobeNewswire, Inc.    add       article
# 4                                         NewsRX, LLC    add       article
# 5                                         NewsRX, LLC    add       article
# 6                                          Condé Nast    add       article
# 7                                   Normans Media Ltd    add       article
# 8                                         NewsRX, LLC    add       article
# 9                                   Normans Media Ltd    add       article
# 10                             Namibia Media Holdings    add       article
# 11                                        NewsRX, LLC    add       article
# 12                                    Ventures Africa    add       article
# 13                                         Shaw Media    add       article
# 14                                        NewsRX, LLC    add       article
# 15                               The Associated Press    add       article
# 16                    American City Business Journals    add       article
# 17                                        NewsRX, LLC    add       article
# 18                                        NewsRX, LLC    add       article
# 19  Newsquest (Herald and Times) LTD and Newsquest...    add       article
#
#                        date  year  \
# 0   2017-03-13 00:00:00.000  2017
# 1   2017-02-23 00:00:00.000  2017
# 2   2017-10-20 00:00:00.000  2017
# 3   2017-01-12 14:00:04.057  2017
# 4   2017-08-17 00:00:00.000  2017
# 5   2017-08-29 00:00:00.000  2017
# 6   2017-04-01 00:00:00.000  2017
# 7   2017-02-24 00:00:00.000  2017
# 8   2017-02-09 00:00:00.000  2017
# 9   2017-07-11 00:00:00.000  2017
# 10  2017-01-27 00:00:00.000  2017
# 11  2017-07-07 00:00:00.000  2017
# 12  2017-06-01 00:00:00.000  2017
# 13  2017-06-19 00:00:00.000  2017
# 14  2017-09-28 00:00:00.000  2017
# 15  2017-09-28 22:23:58.677  2017
# 16  2017-12-28 00:00:00.000  2017
# 17  2017-03-28 00:00:00.000  2017
# 18  2017-12-21 00:00:00.000  2017
# 19  2017-03-08 00:00:00.000  2017
#
#                                             full_text
# 0   CA Technologies; Are You Getting the Most Valu...
# 1   Certified Security Solutions, Inc. CSS Release...
# 2   Harman Kardon launches smart speaker with Micr...
# 3   Izenda Partners with Orion Communications to P...
# 4   Qstream; HubSpot Signs Global Agreement with Q...
# 5   Aerohive Networks, Inc. Patent Application Tit...
# 6   CHASING THE PHANTOM; A MYSTERIOUS RUSSIAN HACK...
# 7   Why Shares of Hewlett Packard Enterprise Dropp...
# 8   ASCENTIVE LLC; Patent Issued for System for Ne...
# 9   Infor Amplifies Customer Service by Delivering...
# 10  Newsday Selects NEWSCYCLE Solutions for Hosted...
# 11  River Logic, Inc. River Logic Quickly Fills Pr...
# 12  United States : IBM Leads Countrys First Nanot...
# 13  Why is virtual reality taking so long to take ...
# 14  Myriad Mobile; Bushel(TM) Launches Ecosystem w...
# 15  BC-GLF--Webcom-Saunders-59,2nd Ld-Writethru BC...
# 16  Android users will get HQ Trivia app by new ye...
# 17  Fenergo; Fenergo Signs First Spanish Banking C...
# 18  Medical Records; Patent Issued for Fault Toler...
# 19  Software firm not fazed by US health reforms C...
#
# [20 rows x 45 columns]

# %%
df = pd.read_excel(r"software_600.xlsx", index_col=0) ## Reading in data
#df_save = df.reset_index(inplace=False, drop = True)
df = df.reset_index(inplace=False, drop = True)
df
# Out:
#                             an  \
# 0    PNN0000020180426ee4p00006
# 1    INVDAI0020150827eb8r00011
# 2    CNEWSN0020150403eb4200008
# 3    NDRSNH0020200312eg3a00003
# 4    LBA0000020200124eg1o02o7x
# ..                         ...
# 595  WATERTWN20141208eac30001o
# 596  TELWK00020130531e96500010
# 597  INTA000020140410ea4a00009
# 598  ATRTAL0020200423eg4n000s8
# 599  BWR0000020170710ed7a0009v
#
#                                                  title  \
# 0    Creaform and Metrologic Group Announce Worldwi...
# 1    4 Growth Stocks Make Case For "New Leader" Status
# 2    Microsoft puts kibosh on Kinect for Windows se...
# 3    County Council approves $850,000 for additiona...
# 4    Novartis, GBT sickle cell drugs too expensive,...
# ..                                                 ...
# 595  A REVIEW OF FOUR APPS THAT WILL HELP YOU SHOP ...
# 596  Transaction Network Services; TNS Unveils Uniq...
# 597   Red Hat introduces new OpenStack training course
# 598  Dragontail Systems Enters U.S. Market, Launche...
# 599  Protivix Hires Chad Ehmke and Launches Special...
#
#                                                snippet  \
# 0    Metrologic Group and Creaform have entered int...
# 1    The IPO Leaders screen can hold up to 16 stock...
# 2    Last year when Microsoft announced an adapter ...
# 3    ANDERSON — The Madison County Council approved...
# 4    * U.S. group suggests SCD drugs too costly\n\n...
# ..                                                 ...
# 595  Want to save some cash while holiday shopping?...
# 596  2013 JUN 5 (VerticalNews) -- By a News Reporte...
# 597  Red Hat, Inc. (NYSE: RHT) said it has announce...
# 598  NEW YORK, April 23 -- Dragontail Systems Limit...
# 599  \nFRISCO, Texas--(BUSINESS WIRE)--July 10, 201...
#
#                                                   body  \
# 0    Speed and volumetric accuracy\n\nThe CUBE-R™ e...
# 1    Still, it makes sense to fill your watch list ...
# 2    Starting today, Microsoft will no longer be ma...
# 3    The additional $16,637 will cover the expenses...
# 4    * Report may change after public comments\n\nB...
# ..                                                 ...
# 595  I found four apps to recommend after testing m...
# 596  TNS has partnered with leading mobile and land...
# 597  The course is available via traditional and vi...
# 598  Dragontail Systems Limited (ASX: DTS), a softw...
# 599  Protivix's initial offerings will include solu...
#
#                                              full_text  \
# 0    Creaform and Metrologic Group Announce Worldwi...
# 1    4 Growth Stocks Make Case For "New Leader" Sta...
# 2    Microsoft puts kibosh on Kinect for Windows se...
# 3    County Council approves $850,000 for additiona...
# 4    Novartis, GBT sickle cell drugs too expensive,...
# ..                                                 ...
# 595  A REVIEW OF FOUR APPS THAT WILL HELP YOU SHOP ...
# 596  Transaction Network Services; TNS Unveils Uniq...
# 597  Red Hat introduces new OpenStack training cour...
# 598  Dragontail Systems Enters U.S. Market, Launche...
# 599  Protivix Hires Chad Ehmke and Launches Special...
#
#      Does it mention an innovation (yes,no,unsure)?  What is the company?  \
# 0                                               NaN                   NaN
# 1                                               NaN                   NaN
# 2                                               NaN                   NaN
# 3                                               NaN                   NaN
# 4                                               NaN                   NaN
# ..                                              ...                   ...
# 595                                             NaN                   NaN
# 596                                             NaN                   NaN
# 597                                             NaN                   NaN
# 598                                             NaN                   NaN
# 599                                             NaN                   NaN
#
#      Where is company mentioned (title,body,snippet,all)?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 595                                                NaN
# 596                                                NaN
# 597                                                NaN
# 598                                                NaN
# 599                                                NaN
#
#      What is the product name?  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 595                        NaN
# 596                        NaN
# 597                        NaN
# 598                        NaN
# 599                        NaN
#
#      Where is the product name mentioned(title,body,snippet,all)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 595                                                NaN
# 596                                                NaN
# 597                                                NaN
# 598                                                NaN
# 599                                                NaN
#
#      What could indicate that this is a product (for use in our algorithms, e.g. TM,R,C,CAPITAL LETTERS, Quotes,Used with certain key phrases or words etc.)?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 595                                                NaN
# 596                                                NaN
# 597                                                NaN
# 598                                                NaN
# 599                                                NaN
#
#      Features of the product, if mentioned assignee YN_INNOVATION
# 0                                      NaN    Diggy           yes
# 1                                      NaN    Diggy            no
# 2                                      NaN    Diggy            no
# 3                                      NaN    Diggy            no
# 4                                      NaN    Diggy            no
# ..                                     ...      ...           ...
# 595                                    NaN    Aditi            no
# 596                                    NaN    Aditi           yes
# 597                                    NaN    Aditi            no
# 598                                    NaN    Aditi           yes
# 599                                    NaN    Diggy            no
#
# [600 rows x 14 columns]

# %%
df_new = pd.read_csv("/home/asr8r/git/dspg21binn/data/DNA_Food_Articles_2017_no_rep.csv", index_col=0) ## Reading in data
#df_save = df.reset_index(inplace=False, drop = True)
df_new = df_new.reset_index(inplace=False, drop = True)
df_new
# Out:
#           index                                          copyright  \
# 0            15  © Copyright 2017 Journal of Engineering via Ve...
# 1            18  © Copyright 2017 Computer Weekly News via via ...
# 2            26  Copyright 2017 Telecompaper. All Rights Reserv...
# 3            36  © Copyright 2017 GlobeNewswire, Inc. All Right...
# 4            57  © Copyright 2017 Computer Weekly News via via ...
# ...         ...                                                ...
# 101138  1293014  © Copyright 2017 The Taipei Times. All rights ...
# 101139  1293020             Distributed by Tribune Content Agency
# 101140  1293029      © Copyright 2017 Blood Weekly via NewsRx.com
# 101141  1293068   © 2017, M2 Communications. All rights reserved.
# 101142  1293089  Copyright 2017 Thomson Reuters. All Rights Res...
#
#                                             subject_codes  art  \
# 0                                                  ,ccat,  NaN
# 1                                                  ,ccat,  NaN
# 2                 ,ccat,c22,cprdop,c24,ncat,nfact,nfcpin,  NaN
# 3                    ,cpartn,ccpint,npress,c11,ccat,ncat,  NaN
# 4                                                  ,ccat,  NaN
# ...                                                   ...  ...
# 101138  ,ghack,nnam,gcat,gcrim,ncat,nfact,nfce,nfcpex,...  NaN
# 101139   ,gamer,guni,gcat,gedu,gspo,ncat,nfact,nfce,nrgn,  NaN
# 101140     ,gcancr,gcrese,ccat,gleuk,gcat,ghea,gmed,gsci,  NaN
# 101141                                   ,guni,gcat,gedu,  NaN
# 101142     ,c181,cacqu,c18,cactio,ccat,ncat,nfact,nfcpin,  NaN
#
#         modification_datetime  \
# 0               1489442488000
# 1               1487890959000
# 2               1508513602000
# 3               1484229727000
# 4               1503007605000
# ...                       ...
# 101138          1491373095000
# 101139          1494177346000
# 101140          1501193383000
# 101141          1501902131000
# 101142          1501584075000
#
#                                                      body  \
# 0       Those respondents with advanced full life cycl...
# 1       The Access Valve for ThingWorx integrates an o...
# 2       Cortana on the new speaker will look up inform...
# 3       According to Lee Nagel, vice president of mark...
# 4       Given its aggressive plans to take more market...
# ...                                                   ...
# 101138  Its targets included banks, financial and trad...
# 101139  COMMITMENTS\n\nCameron Murray\n\nPosition: Saf...
# 101140  Our news journalists obtained a quote from the...
# 101141  Activision CEO Eric Hirshberg said that the re...
# 101142  * Nextgen Healthcare agrees to acquire Eagledr...
#
#         company_codes_occur_ticker_exchange  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 101138                                  NaN
# 101139                                  NaN
# 101140                                  NaN
# 101141                                  NaN
# 101142                                  NaN
#
#                                       company_codes_occur  \
# 0                                                ,comasc,
# 1                                                     NaN
# 2                    ,mcrost,harmki,gognew,bstbuy,amzcom,
# 3                                   ,orncmi,onlnfr,linkd,
# 4                                                ,hubspo,
# ...                                                   ...
# 101138                         ,usagov,kaspy,frbny,banbk,
# 101139  ,dalcow,wvgsty,uvclla,uowyom,twnit,smunii,pens...
# 101140                                       ,ntnct,elsv,
# 101141                                           ,actvis,
# 101142                                       ,qsii,nhisi,
#
#                   company_codes_about company_codes_lineage  ...  \
# 0                            ,comasc,                   NaN  ...
# 1                                 NaN                   NaN  ...
# 2       ,mcrost,harint,bstbuy,harmki,              ,sansel,  ...
# 3                                 NaN                   NaN  ...
# 4                            ,hubspo,                   NaN  ...
# ...                               ...                   ...  ...
# 101138            ,kaspy,frbny,banbk,                   NaN  ...
# 101139                ,dbpuqw,uowyom,                   NaN  ...
# 101140                    ,ntnct,ibm,                   NaN  ...
# 101141                       ,actvis,                   NaN  ...
# 101142                         ,qsii,                   NaN  ...
#
#                                             company_codes  \
# 0                                  ,comasc,comasc,comasc,
# 1                                                     NaN
# 2       ,harmki,amzcom,amzcom,bstbuy,bstbuy,gognew,gog...
# 3         ,linkd,linkd,onlnfr,onlnfr,orncmi,orncmi,twnit,
# 4                           ,hubspo,hubspo,hubspo,salesf,
# ...                                                   ...
# 101138  ,banbk,frbny,kaspy,banbk,banbk,frbny,frbny,kas...
# 101139  ,uowyom,bllsty,bllsty,botncg,botncg,brghyu,brg...
# 101140                  ,elsv,elsv,ntnct,ntnct,ibm,ntnct,
# 101141                      ,actvis,actvis,bllsty,actvis,
# 101142                       ,qsii,nhisi,nhisi,qsii,qsii,
#
#                                            industry_codes  \
# 0           ,imobsoft,i3302,i330202,i3302021,icomp,itech,
# 1       ,isecpri,iioft,i3302,i330202,i3302021,i3303,ic...
# 2       ,i34532,i3302,icnp,idurhg,ielec,ihome,itech,i3...
# 3              ,ibisw,i3302021,i3302,i330202,icomp,itech,
# 4            ,icomp,i3302,itech,i330202,i3302021,ientrps,
# ...                                                   ...
# 101138  ,i81401,i814,ibnk,ifinal,i3302,i330202,i330202...
# 101139                         ,i3302,i83941,icomp,itech,
# 101140                                       ,i8394,ibcs,
# 101141  ,i3302,i330202,i3302021,icnp,icomp,igamsof,ilg...
# 101142               ,icomp,i3302,itech,i330202,i3302021,
#
#                                                     title  \
# 0       CA Technologies; Are You Getting the Most Valu...
# 1       Certified Security Solutions, Inc. CSS Release...
# 2       Harman Kardon launches smart speaker with Micr...
# 3       Izenda Partners with Orion Communications to P...
# 4       Qstream; HubSpot Signs Global Agreement with Q...
# ...                                                   ...
# 101138  More proof N Korea linked to Bangladesh heist:...
# 101139           2018 Wyoming football recruiting tracker
# 101140  Oncology - Acute Myelogenous Leukemia; New Fin...
# 101141  Activision CEO says remasters, reboots possibl...
# 101142  BRIEF-Nextgen Healthcare agrees to acquire Eag...
#
#         publication_datetime                 publisher_name action  \
# 0              1489363200000                    NewsRX, LLC    add
# 1              1487808000000                    NewsRX, LLC    add
# 2              1508457600000                Telecompaper BV    add
# 3              1484229604057            GlobeNewswire, Inc.    add
# 4              1502928000000                    NewsRX, LLC    add
# ...                      ...                            ...    ...
# 101138         1491350400000             Liberty Times Ltd.    add
# 101139         1494115200000         Tribune Content Agency    add
# 101140         1501113600000                    NewsRX, LLC    add
# 101141         1501804800000              Normans Media Ltd    add
# 101142         1501584063000  Thomson Reuters (Markets) LLC    add
#
#        document_type                     date  year  \
# 0            article  2017-03-13 00:00:00.000  2017
# 1            article  2017-02-23 00:00:00.000  2017
# 2            article  2017-10-20 00:00:00.000  2017
# 3            article  2017-01-12 14:00:04.057  2017
# 4            article  2017-08-17 00:00:00.000  2017
# ...              ...                      ...   ...
# 101138       article  2017-04-05 00:00:00.000  2017
# 101139       article  2017-05-07 00:00:00.000  2017
# 101140       article  2017-07-27 00:00:00.000  2017
# 101141       article  2017-08-04 00:00:00.000  2017
# 101142       article  2017-08-01 10:41:03.000  2017
#
#                                                 full_text
# 0       CA Technologies; Are You Getting the Most Valu...
# 1       Certified Security Solutions, Inc. CSS Release...
# 2       Harman Kardon launches smart speaker with Micr...
# 3       Izenda Partners with Orion Communications to P...
# 4       Qstream; HubSpot Signs Global Agreement with Q...
# ...                                                   ...
# 101138  More proof N Korea linked to Bangladesh heist:...
# 101139  2018 Wyoming football recruiting tracker May 0...
# 101140  Oncology - Acute Myelogenous Leukemia; New Fin...
# 101141  Activision CEO says remasters, reboots possibl...
# 101142  BRIEF-Nextgen Healthcare agrees to acquire Eag...
#
# [101143 rows x 45 columns]

# %%
## Balancing target class 

df_yes = df[df.YN_INNOVATION == 'yes']
df_no = df[df.YN_INNOVATION == 'no']

if len(df_yes) == len(df_no):
    df_yes = df_yes.append(df_no)
    df = df_yes
    
elif len(df_yes) > len(df_no):
    df_yes = df_yes.sample(n=len(df_no), random_state = 65432)
    df_yes = df_yes.append(df_no)
    df = df_yes
    
elif len(df_no) > len(df_yes):
    df_no = df_no.sample(n=len(df_yes), random_state = 65432)
    df_yes = df_yes.append(df_no)
    df = df_yes
    
df = df.sample(n=len(df), random_state = 65432).reset_index(inplace=False, drop = True)

    
print("Value counts for target variable:\n",df.YN_INNOVATION.value_counts())

## Encoding target variable

le = preprocessing.LabelEncoder()
df.YN_INNOVATION = le.fit_transform(df.YN_INNOVATION)
print("\n\n\nThe target variable classes are:", le.classes_)
# Out:
# Value counts for target variable:
#  yes    222
# no     222
# Name: YN_INNOVATION, dtype: int64
#
#
#
# The target variable classes are: ['no' 'yes']

# %%
## NLP Models from Hugging Face, pretrained_weights object is changed according to required model
model_class, tokenizer_class, pretrained_weights = (AutoModel, 
                                                    AutoTokenizer, 
                                                    'distilbert-base-uncased')
                                                 
# Load pretrained model/tokenizer
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)

#Tokenize
tokenized = df['full_text'].apply((lambda x: tokenizer.encode(x, add_special_tokens=True, padding=True, 
                                                          truncation=True,max_length=512)))


#Train Data
max_len = 0
for i in tokenized.values:
    if len(i) > max_len:
        max_len = len(i)

padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized.values])

np.array(padded).shape
attention_mask = np.where(padded != 0, 1, 0)
attention_mask.shape

input_ids = torch.tensor(padded)  
attention_mask = torch.tensor(attention_mask)

with torch.no_grad():
    last_hidden_states = model(input_ids, attention_mask=attention_mask)
    
    
    


#Test/Train  
features = last_hidden_states[0][:,0,:].numpy()
labels = df['YN_INNOVATION']
train_features, test_features, train_labels, test_labels = train_test_split(features, labels)

#Logistic Regression
lr_clf = LogisticRegression(solver="sag")
lr_clf.fit(train_features, train_labels)

#Accuracy
lr_clf.score(test_features, test_labels)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /home/asr8r/.conda/envs/akbert/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.918918918918919

# %%
tokenized_new =  df_new['full_text'].apply((lambda x: tokenizer.encode(x, add_special_tokens=True, padding=True, 
                                                          truncation=True,max_length=512)))

#New Data

max_len = 0
for i in tokenized_new.values:
    if len(i) > max_len:
        max_len = len(i)

padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized_new.values])

np.array(padded).shape
attention_mask = np.where(padded != 0, 1, 0)
attention_mask.shape

input_ids = torch.tensor(padded)  
attention_mask = torch.tensor(attention_mask)

with torch.no_grad():
    last_hidden_states_new = model(input_ids, attention_mask=attention_mask)

features_new = last_hidden_states_new[0][:,0,:].numpy()




predicted_y = clf.predict(features_new)
pred_prob = clf.predict_proba(features_new)[:, 1]

df_new["predicted_Innovation"] = predicted_y
df_new
